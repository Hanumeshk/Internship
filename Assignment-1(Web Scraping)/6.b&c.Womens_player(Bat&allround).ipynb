# %% [markdown]
# # 6) b) Top 10 women’s ODI Batting players along with the records of their team and rating.

# %% [markdown]
# # Importing Libraries

# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests
import re
from urllib.request import urlopen
import numpy as np

# %%
url='https://www.icc-cricket.com/rankings/womens/player-rankings/odi'
page=requests.get(url)
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="ICC Women's ODI Player Rankings | ICC" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official International Cricket Council rankings for ODI match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official International Cricket Council rankings for ODI match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC Women's ODI Player Rankings | ICC" property="og:title"/>
# ...

# %%
other_position=[]
for i in soup.find_all('span',class_="rankings-table__pos-number"):
    other_position.append(i.text)
other_position
# Out:
# ['\n                                    2\n                                ',
#  '\n                                    3\n                                ',
#  '\n                                    4\n                                ',
#  '\n                                    5\n                                ',
#  '\n                                    6\n                                ',
#  '\n                                    7\n                                ',
#  '\n                                    8\n                                ',
#  '\n                                    9\n                                ',
#  '\n                                    10\n                                ',
#  '\n                                    2\n                                ',
#  '\n                                    3\n                                ',
#  '\n                                    4\n                                ',
# ...

# %%
positions=pd.DataFrame(other_position,columns=['position'])
positions.loc[0:8]
# Out:
#                                             position
# 0  \n                                    2\n     ...
# 1  \n                                    3\n     ...
# 2  \n                                    4\n     ...
# 3  \n                                    5\n     ...
# 4  \n                                    6\n     ...
# 5  \n                                    7\n     ...
# 6  \n                                    8\n     ...
# 7  \n                                    9\n     ...
# 8  \n                                    10\n    ...

# %%
other_pos=positions['position'].str.split('\n',expand=True)
posi=other_pos.loc[0:8,1:1]
posi
# Out:
#                                         1
# 0                                       2
# 1                                       3
# 2                                       4
# 3                                       5
# 4                                       6
# 5                                       7
# 6                                       8
# 7                                       9
# 8                                      10

# %%
team=[]
for i in soup.find_all('span',class_="table-body__logo-text"):
    team.append(i.text)
team
# Out:
# ['ENG',
#  'AUS',
#  'SA',
#  'AUS',
#  'AUS',
#  'IND',
#  'NZ',
#  'IND',
#  'ENG',
#  'SA',
#  'AUS',
#  'AUS',
#  'IND',
#  'SA',
#  'SA',
#  'ENG',
#  'ENG',
#  'WI',
#  'AUS',
#  'SA',
#  'WI',
#  'NZ',
#  'AUS',
#  'IND',
#  'AUS',
#  'ENG',
#  'IND']

# %%
teams=pd.DataFrame(team)
team=teams.loc[0:8]
team
# Out:
#      0
# 0  ENG
# 1  AUS
# 2   SA
# 3  AUS
# 4  AUS
# 5  IND
# 6   NZ
# 7  IND
# 8  ENG

# %%
other_bat=[]
for i in soup.find_all('td',class_="table-body__cell name"):
    other_bat.append(i.text)

other_bat
# Out:
# ['\nNatalie Sciver\n',
#  '\nBeth Mooney\n',
#  '\nLaura Wolvaardt\n',
#  '\nMeg Lanning\n',
#  '\nRachael Haynes\n',
#  '\nMithali Raj\n',
#  '\nAmy Satterthwaite\n',
#  '\nSmriti Mandhana\n',
#  '\nTammy Beaumont\n',
#  '\nShabnim Ismail\n',
#  '\nJess Jonassen\n',
#  '\nMegan Schutt\n',
#  '\nJhulan Goswami\n',
#  '\nMarizanne Kapp\n',
#  '\nAyabonga Khaka\n',
#  '\nAnya Shrubsole\n',
#  '\nKate Cross\n',
#  '\nHayley Matthews\n',
#  '\nEllyse Perry\n',
#  '\nMarizanne Kapp\n',
#  '\nHayley Matthews\n',
#  '\nAmelia Kerr\n',
#  '\nAshleigh Gardner\n',
#  '\nDeepti Sharma\n',
#  '\nJess Jonassen\n',
#  '\nKatherine Brunt\n',
#  '\nJhulan Goswami\n']

# %%
bat=pd.DataFrame(other_bat,columns=['Player'])
bat
# Out:
#                    Player
# 0      \nNatalie Sciver\n
# 1         \nBeth Mooney\n
# 2     \nLaura Wolvaardt\n
# 3         \nMeg Lanning\n
# 4      \nRachael Haynes\n
# 5         \nMithali Raj\n
# 6   \nAmy Satterthwaite\n
# 7     \nSmriti Mandhana\n
# 8      \nTammy Beaumont\n
# 9      \nShabnim Ismail\n
# 10      \nJess Jonassen\n
# 11       \nMegan Schutt\n
# 12     \nJhulan Goswami\n
# 13     \nMarizanne Kapp\n
# 14     \nAyabonga Khaka\n
# 15     \nAnya Shrubsole\n
# 16         \nKate Cross\n
# 17    \nHayley Matthews\n
# 18       \nEllyse Perry\n
# 19     \nMarizanne Kapp\n
# 20    \nHayley Matthews\n
# 21        \nAmelia Kerr\n
# 22   \nAshleigh Gardner\n
# 23      \nDeepti Sharma\n
# 24      \nJess Jonassen\n
# 25    \nKatherine Brunt\n
# 26     \nJhulan Goswami\n

# %%
Batsman=bat['Player'].str.split('\n',expand=True)
other_batsman=Batsman.loc[0:8,1:1]
other_batsman
# Out:
#                    1
# 0     Natalie Sciver
# 1        Beth Mooney
# 2    Laura Wolvaardt
# 3        Meg Lanning
# 4     Rachael Haynes
# 5        Mithali Raj
# 6  Amy Satterthwaite
# 7    Smriti Mandhana
# 8     Tammy Beaumont

# %%
rating=[]
for i in soup.find_all('td',class_="table-body__cell u-text-right rating"):
    rating.append(i.text)
rating
# Out:
# ['750',
#  '748',
#  '722',
#  '710',
#  '701',
#  '686',
#  '681',
#  '669',
#  '659',
#  '732',
#  '725',
#  '722',
#  '663',
#  '662',
#  '635',
#  '629',
#  '617',
#  '612',
#  '374',
#  '359',
#  '338',
#  '335',
#  '269',
#  '249',
#  '245',
#  '221',
#  '217']

# %%
other_rating=pd.DataFrame(rating)
ratings=other_rating.loc[0:8]
ratings
# Out:
#      0
# 0  750
# 1  748
# 2  722
# 3  710
# 4  701
# 5  686
# 6  681
# 7  669
# 8  659

# %%
pos=pd.concat([posi,other_batsman,team,ratings],axis=1)
pos
# Out:
#                                         1                  1    0    0
# 0                                       2     Natalie Sciver  ENG  750
# 1                                       3        Beth Mooney  AUS  748
# 2                                       4    Laura Wolvaardt   SA  722
# 3                                       5        Meg Lanning  AUS  710
# 4                                       6     Rachael Haynes  AUS  701
# 5                                       7        Mithali Raj  IND  686
# 6                                       8  Amy Satterthwaite   NZ  681
# 7                                       9    Smriti Mandhana  IND  669
# 8                                      10     Tammy Beaumont  ENG  659

# %% [markdown]
# # B.Womens Top 10 Batsman

# %%
pos.columns=["Position","Player","Team","Points"]
Batting=pos
Batting
# Out:
#                                  Position             Player Team Points
# 0                                       2     Natalie Sciver  ENG    750
# 1                                       3        Beth Mooney  AUS    748
# 2                                       4    Laura Wolvaardt   SA    722
# 3                                       5        Meg Lanning  AUS    710
# 4                                       6     Rachael Haynes  AUS    701
# 5                                       7        Mithali Raj  IND    686
# 6                                       8  Amy Satterthwaite   NZ    681
# 7                                       9    Smriti Mandhana  IND    669
# 8                                      10     Tammy Beaumont  ENG    659

# %%
player=[]
for i in soup.find_all('div',class_="rankings-block__top-player"):
    player.append(i.text)
player
# Out:
# ['\n\n\n\n                                1\n                            \n\n\n\n\n(3)\nThis player has moved up in the rankings since the previous rankings update\n\n\n\n\nAlyssa Healy\n\n\nAUS\n                            785\n\n\n\n\n\n',
#  '\n\n\n\n                                1\n                            \n\n\n(0)\n\n\n\n\nSophie Ecclestone\n\n\nENG\n                            771\n\n\n\n\n\n',
#  '\n\n\n\n                                1\n                            \n\n\n\n\n(1)\nThis player has moved up in the rankings since the previous rankings update\n\n\n\n\nNatalie Sciver\n\n\nENG\n                            393\n\n\n\n\n\n']

# %%
players=pd.DataFrame(player,columns=['position'])
players
# Out:
#                                             position
# 0  \n\n\n\n                                1\n   ...
# 1  \n\n\n\n                                1\n   ...
# 2  \n\n\n\n                                1\n   ...

# %%
top_player=players['position'].str.split('\n',expand=True)
top_player.loc[:,4:20]
# Out:
#                                   4                             5  6  7    8   \
# 0                                  1
# 1                                  1                                      (0)
# 2                                  1
#
#   9    10                                                 11 12  \
# 0     (3)  This player has moved up in the rankings since...
# 1
# 2     (1)  This player has moved up in the rankings since...
#
#                   13 14 15              16                               17  \
# 0                             Alyssa Healy
# 1  Sophie Ecclestone                   ENG                              771
# 2                           Natalie Sciver
#
#   18   19                               20
# 0     AUS                              785
# 1
# 2     ENG                              393

# %%
df=top_player.loc[0:0,[4,16,19,20]]
df1=df
df1
# Out:
#                                   4             16   19  \
# 0                                  1  Alyssa Healy  AUS
#
#                                 20
# 0                              785

# %%
allround=top_player.loc[2:2,[4,16,19,20]]
allround
# Out:
#                                   4               16   19  \
# 2                                  1  Natalie Sciver  ENG
#
#                                 20
# 2                              393

# %%
allround.columns=['Position','Player','Team','Points']
top_allround=allround
top_allround
# Out:
#                             Position          Player Team  \
# 2                                  1  Natalie Sciver  ENG
#
#                             Points
# 2                              393

# %%
df1.columns=['Position','Player','Team','Points']
df2=df1
df2
# Out:
#                             Position        Player Team  \
# 0                                  1  Alyssa Healy  AUS
#
#                             Points
# 0                              785

# %%
Top_batsman=pd.concat([df2,Batting],axis=0,ignore_index=True)
Top_batsman
# Out:
#                                  Position             Player Team  \
# 0                                       1       Alyssa Healy  AUS
# 1                                       2     Natalie Sciver  ENG
# 2                                       3        Beth Mooney  AUS
# 3                                       4    Laura Wolvaardt   SA
# 4                                       5        Meg Lanning  AUS
# 5                                       6     Rachael Haynes  AUS
# 6                                       7        Mithali Raj  IND
# 7                                       8  Amy Satterthwaite   NZ
# 8                                       9    Smriti Mandhana  IND
# 9                                      10     Tammy Beaumont  ENG
#
#                             Points
# 0                              785
# 1                              750
# 2                              748
# 3                              722
# 4                              710
# ...

# %% [markdown]
# # 6) c) Top 10 women’s ODI all-rounder along with the records of their team and rating.

# %%
allround
# Out:
#                             Position          Player Team  \
# 2                                  1  Natalie Sciver  ENG
#
#                             Points
# 2                              393

# %%
all_pos=other_pos.loc[18:26,1:1]
all_pos
# Out:
#                                          1
# 18                                       2
# 19                                       3
# 20                                       4
# 21                                       5
# 22                                       6
# 23                                       7
# 24                                       8
# 25                                       9
# 26                                      10

# %%
all_team=teams.loc[18:26]
all_team
# Out:
#       0
# 18  AUS
# 19   SA
# 20   WI
# 21   NZ
# 22  AUS
# 23  IND
# 24  AUS
# 25  ENG
# 26  IND

# %%
all_player=Batsman.loc[18:26,1:1]
all_player
# Out:
#                    1
# 18      Ellyse Perry
# 19    Marizanne Kapp
# 20   Hayley Matthews
# 21       Amelia Kerr
# 22  Ashleigh Gardner
# 23     Deepti Sharma
# 24     Jess Jonassen
# 25   Katherine Brunt
# 26    Jhulan Goswami

# %%
all_rating=other_rating.loc[18:26]
all_rating
# Out:
#       0
# 18  374
# 19  359
# 20  338
# 21  335
# 22  269
# 23  249
# 24  245
# 25  221
# 26  217

# %%
all_round=pd.concat([all_pos,all_player,all_team,all_rating],axis=1,)
all_round
# Out:
#                                          1                 1    0    0
# 18                                       2      Ellyse Perry  AUS  374
# 19                                       3    Marizanne Kapp   SA  359
# 20                                       4   Hayley Matthews   WI  338
# 21                                       5       Amelia Kerr   NZ  335
# 22                                       6  Ashleigh Gardner  AUS  269
# 23                                       7     Deepti Sharma  IND  249
# 24                                       8     Jess Jonassen  AUS  245
# 25                                       9   Katherine Brunt  ENG  221
# 26                                      10    Jhulan Goswami  IND  217

# %%
all_round.columns=["Position","Player","Team","Points"]
df6=all_round
df6
# Out:
#                                   Position            Player Team Points
# 18                                       2      Ellyse Perry  AUS    374
# 19                                       3    Marizanne Kapp   SA    359
# 20                                       4   Hayley Matthews   WI    338
# 21                                       5       Amelia Kerr   NZ    335
# 22                                       6  Ashleigh Gardner  AUS    269
# 23                                       7     Deepti Sharma  IND    249
# 24                                       8     Jess Jonassen  AUS    245
# 25                                       9   Katherine Brunt  ENG    221
# 26                                      10    Jhulan Goswami  IND    217

# %%
allround_players=pd.concat([allround,df6],axis=0,ignore_index=True)
allround_players
# Out:
#                                  Position            Player Team  \
# 0                                       1    Natalie Sciver  ENG
# 1                                       2      Ellyse Perry  AUS
# 2                                       3    Marizanne Kapp   SA
# 3                                       4   Hayley Matthews   WI
# 4                                       5       Amelia Kerr   NZ
# 5                                       6  Ashleigh Gardner  AUS
# 6                                       7     Deepti Sharma  IND
# 7                                       8     Jess Jonassen  AUS
# 8                                       9   Katherine Brunt  ENG
# 9                                      10    Jhulan Goswami  IND
#
#                             Points
# 0                              393
# 1                              374
# 2                              359
# 3                              338
# 4                              335
# ...
